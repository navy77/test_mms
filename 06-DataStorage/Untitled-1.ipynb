# %%
import clickhouse_connect

client = clickhouse_connect.get_client(host='192.168.0.191',port=8123, username='default', password='maibok')

# %%
import psycopg2
connection = psycopg2.connect(
    host="localhost",
    port=5432,
    user="postgres",
    password="postgres",
    dbname="iiot_db")

# %%
import pandas as pd
from sqlalchemy import create_engine
engine1 = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/iiot_db")

column_query = "SELECT process, column_name, column_type,column_key  FROM columns_register_tb"
df_column = pd.read_sql(column_query, engine1)
print(df_column)

# %%
import pandas as pd
from sqlalchemy import create_engine
engine1 = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/iiot_db")

device_query = "SELECT process, device  FROM device_register_tb"
df_device = pd.read_sql(device_query, engine1)
print(df_device)

# %%
import pandas as pd
from datetime import datetime, timedelta

def get_data_from_clickhouse(type,period_minutes):
    now = datetime.now()
    start_time = (now - timedelta(minutes=period_minutes)).strftime("%Y-%m-%d %H:%M:%S")
    end_time = now.strftime("%Y-%m-%d %H:%M:%S")
    query = f"SELECT * FROM {type}_tb WHERE created_at BETWEEN  '{start_time}' AND  '{end_time}'  order by created_at desc "

    if type == "data":
        df_data_raw = client.query_df(query)
        return df_data_raw
    elif type == "status":
        df_status_raw = client.query_df(query)
        return df_status_raw
    elif type == "alarm":
        df_alarm_raw = client.query_df(query)
        return df_alarm_raw

df_raw = get_data_from_clickhouse("data",60)
df_raw.groupby('process').count()
print(df_raw)
